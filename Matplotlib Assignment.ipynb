# %%
## Import thr libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a visualization library for python. It is built in package so that we don't need to install it. It is used for plotting different types of graphs and plots to visualize our data as per our needs. so that we can easily grasp the overview of the dataset. It is easy to learn from a visualization rather than learing from some numbers.
# 1. line graph
# 2. scatter plot
# 3. histogram
# 4. pie chart
# 5. 3d plots

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# ## Scatter plot is used for plotting pair of data in x,y cordinate system.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50) 
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.title('This is my scatter plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
## subplots are used for creating multiple plots inside one single plot. or to show data in 3d cordinate system

# %%
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 2, ncols = 1)
ax1.set_xlabel('X1')
ax1.plot(x1,y1)
ax1.plot(x2,y2)
ax2.plot(x3,y3)
ax2.plot(x4,y4)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
#
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
## Bar plot is a type of plot that we use for different purposes. Bar plot is to represent any kind of categorical dataset.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# ## Box plot is a type of a plot which is used to visualize the distribution of a particular variable/data. It is used for the distribution of the dataset.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x178d9e5f0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x178d9e5d3d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x178d9e5d390>],
#  'medians': [<matplotlib.lines.Line2D at 0x178d7dabb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x178d7daae50>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x178d9ec13d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x178d9ec2750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x178d9ec0b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x178d9ec3610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x178d9ec3c50>],
#  'means': []}
